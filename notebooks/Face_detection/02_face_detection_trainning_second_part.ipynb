# %%
# !git clone https://github.com/yakhyo/retinaface-pytorch.git
# %cd retinaface-pytorch
# Out:
# Cloning into 'retinaface-pytorch'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 194 (delta 45), reused 37 (delta 37), pack-reused 120 (from 1)
# Receiving objects: 100% (194/194), 14.72 MiB | 23.29 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /kaggle/working/retinaface-pytorch

# %%
# !pip install torch torchvision opencv-python numpy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 79.5 MB/s eta 0:00:00
# ...

# %%
# !cp /kaggle/input/face-detection-model-checkpoint/resnet34_checkpoint.ckpt /kaggle/working/retinaface-pytorch/weights
# !cp /kaggle/input/face-detection-model-checkpoint/resnet34_last.pth /kaggle/working/retinaface-pytorch/weights

# %%
# !python train.py \
    --train-data /kaggle/input/wider-face-retinaface/widerface/train \
    --batch-size 32 \
    --num-workers 8 \
    --learning-rate 1e-3 \
    --weight-decay 5e-4 \
    --resume \
    --network resnet34
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Data successfully loaded!
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|███████████████████████████████████████| 83.3M/83.3M [00:00<00:00, 230MB/s]
# Checkpoint successfully loaded from ./weights/resnet34_checkpoint.ckpt
# Training started!
# Epoch: 78/100 | Batch: 10/402 | Loss Localization : 0.4838 | Classification: 0.8117 | Landmarks: 0.5161 | LR: 0.00010000 | Time: 1.2803 s
# ...
